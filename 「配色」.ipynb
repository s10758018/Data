# %% [markdown]
# <a href="https://colab.research.google.com/github/s10758018/Data/blob/master/%E3%80%8C%E9%85%8D%E8%89%B2%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)
library(ggplot2)

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
devtools::install_github('cttobin/ggthemr')
# Out:
# ...
# vctrs      (0.3.4 -> 0.3.5) [CRAN]
# magrittr   (1.5   -> 2.0.1) [CRAN]
# rstudioapi (0.12  -> 0.13 ) [CRAN]
# rprojroot  (1.3-2 -> 2.0.2) [CRAN]
# Installing 4 packages: vctrs, magrittr, rstudioapi, rprojroot
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ✔  checking for file ‘/tmp/RtmpPZwubW/remotes392fed08f/Mikata-Project-ggthemr-3a86e28/DESCRIPTION’
# ─  preparing ‘ggthemr’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#    Removed empty directory ‘ggthemr/README_files’
# ─  building ‘ggthemr_1.1.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggthemr)
# Out:
# Loading required package: ggplot2

# %%
ggthemr("dust")

# %%
NBA1314<-fetch_NBAPlayerStatistics("13-14")
#載入NBA2013~2014的資料

# %%
NBA13140rder<-NBA1314[order(NBA1314$FieldGoalsMade,decreasing=T),]
NBA13140rder[1:30,]#依FieldGoalsMade的由大到小排出30名
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 135 NBA    Kevin Durant     OKL  SF       81          3118
# 227 NBA    Lebron James     MIA  SF       77          2903
# 18  NBA    Carmelo Anthony  NYK  SF       77          2981
# 181 NBA    Blake Griffin    LAC  PF       80          2864
# 231 NBA    Al Jefferson     CHA  C        73          2557
# 7   NBA    Lamarcu Aldridge POR  PF       69          2496
# 112 NBA    Stephen Curry    GSW  PG       78          2843
# 279 NBA    Kevin Love       MIN  PF       77          2797
# 335 NBA    Dirk Nowitzki    DAL  PF       80          2625
# 125 NBA    Demar Derozan    TOR  SG       79          3020
# 103 NBA    Demarcus Cousins SAC  C        71          2296
# 480 NBA    Thaddeus Young   PHI  SF       79          2717
# 454 NBA    John Wall        WAS  PG       82          2980
# 138 NBA    Monta Ellis      DAL  PG       82          3023
# 164 NBA    Paul George      IND  SG       80          2902
# ...

# %%
subset(NBA1314,Team=="TOR")#搜尋TOR隊的欄位資料
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 78  NBA    Dwight Buycks    TOR  PG       14           147
# 121 NBA    Nando Decolo     TOR  PG       47           500
# 125 NBA    Demar Derozan    TOR  SG       79          3020
# 149 NBA    Landry Fields    TOR  SF       30           322
# 185 NBA    Tyler Hansbrough TOR  PF       64           981
# 198 NBA    Chuck Hayes      TOR  PF       61           755
# 236 NBA    Amir Johnson     TOR  PF       77          2214
# 280 NBA    Kyle Lowry       TOR  PG       79          2861
# 334 NBA    Steve Novak      TOR  SF       54           545
# 349 NBA    Patric Patterson TOR  PF       65          1536
# 379 NBA    Terrence Ross    TOR  SG       81          2156
# 383 NBA    John Salmons     TOR  SF       78          1725
# 413 NBA    Julyan Stone     TOR  PG       21           122
# 443 NBA    Jona Valanciunas TOR  C        81          2283
# 446 NBA    Greivis Vasquez  TOR  PG       79          1778
# ...

# %%
NBA1314[grepl("Robin",NBA1314$Name),]#字串收尋名字裡有Robin的球員
# Out:
#     League Name            Team Position GamesPlayed TotalMinutesPlayed
# 278 NBA    Robin Lopez     POR  C        82          2611
# 375 NBA    Nate Robinson   DEN  PG       44           870
# 376 NBA    Thomas Robinson POR  PF       70           877
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 278 355            644                  0           1             ⋯ 26
# 375 164            383                 58         154             ⋯ 36
# 376 141            294                  0           1             ⋯ 23
#     Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 278 84        139    196           2                 908         6
# 375 58          4     92           0                 457         7
# 376 57         20    131           1                 339         3
#     Ejections FlagrantFouls GamesStarted
# 278 0         0             82
# 375 0         0              1
# 376 0         0              0

# %%
qplot(TotalRebounds,TotalMinutesPlayed,data=NBA1314)
#縱軸是TotalRebounds，橫軸是TotalMinutesPlayed的散佈圖
# Out:
# plot without title

# %%
qplot(TotalRebounds,
 TotalMinutesPlayed,
  data = NBA1314,
  color=Position)
  #縱軸是TotalRebounds，橫軸是TotalMinutesPlayed的散佈圖，
  #依照Position分類塗色

# %%
 qplot(TotalRebounds, data = NBA1314, fill = Position)
 #用TotalRebounds畫出直方圖，依照Position分類塗色
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(TotalRebounds,data=NBA1314,
      facets=Position~., binwidth=50)
      #用TotalRebounds畫的直方圖，一圖分開呈現多筆資料，長條寬度每格代表50
# Out:
# plot without title
